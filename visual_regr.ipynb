# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_excel('/Users/mac/Desktop/учеба/проект/avito_data_main.xlsx')
df = df.drop(columns=['item_id'])
df
# Out:
#       category  days_active  has_video  photo_count  \
# 0        Кошки            5      False            4
# 1        Кошки           25      False            2
# 2        Кошки            2      False            4
# 3        Кошки           25      False            2
# 4        Кошки           25      False           10
# ...        ...          ...        ...          ...
# 49968    Кошки           25      False            4
# 49969    Кошки           25      False            1
# 49970    Кошки           11      False            5
# 49971    Кошки           25      False            1
# 49972    Кошки           25      False            2
#
#                                       title  title_length  description_length  \
# 0               Кот 2 года ко всему приучен            27                  22
# 1                     Кошка в дар бесплатно            21                  50
# 2      Красивые здоровые кот и кошка 3 года            36                 216
# ...

# %%
df.sort_values(by='conversion_page_views_favorites_%', ascending=False).head(40)
# Out:
#       category  days_active  has_video  photo_count  \
# 7404    Собаки           25      False            7
# 39576    Кошки           25      False            2
# 46639   Собаки           25      False            5
# 18063    Кошки           15      False            3
# 18065    Кошки           10      False            9
# 46646    Кошки           12      False            3
# 40176   Собаки           25      False            1
# 26330   Собаки           25      False            2
# 6250     Кошки           25      False            1
# 15076    Кошки           25      False            1
# 40111    Кошки           25      False            6
# 15068   Собаки           22      False            1
# 40090    Кошки           18      False            2
# 40065    Кошки           25      False            3
# 22081   Собаки           25      False            1
# 26375    Кошки           25       True            1
# 26381    Кошки           25      False            3
# ...

# %%
sns.scatterplot(x='sentiment', y='conversion_page_views_favorites_contacts_%', data=df)


plt.show()

# %%
df['days_active'].value_counts()
# Out:
# days_active
# 25    25656
# 1      2146
# 2      1739
# 3      1500
# 4      1339
# 6      1188
# 5      1187
# 7      1164
# 24     1035
# 8      1025
# 23      955
# 9       898
# 10      866
# 11      829
# 22      826
# 12      816
# 13      810
# 15      795
# 17      785
# 14      776
# 21      765
# 20      733
# 16      732
# 18      711
# 19      697
# Name: count, dtype: int64
