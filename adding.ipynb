# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_excel('/Users/mac/Desktop/учеба/проект/raw_set.xlsx')
df = df.drop(columns=['item_id'])
df
# Out:
#       category  days_active  has_video  photo_count  \
# 0       Собаки            5      False            4
# 1       Собаки           25      False            2
# 2        Кошки           25      False            4
# 3        Кошки           25       True            1
# 4        Кошки           18      False            4
# ...        ...          ...        ...          ...
# 49995    Кошки           22      False            1
# 49996   Собаки           25      False            1
# 49997    Кошки           25      False            3
# 49998   Собаки            7      False            3
# 49999   Собаки           25      False            4
#
#                                    title  title_length  description_length  \
# 0                     Харизматичный друг            18                1155
# 1                   Собака в добрые руки            20                  49
# 2                             Добрый кот            10                 354
# ...

# %%
df.isnull().sum()
# Out:
# category                      0
# days_active                   0
# has_video                     0
# photo_count                   0
# title                         0
# title_length                  0
# description_length            0
# description_word_count        0
# DescriptionRu                 0
# breed                     34180
# gender                        0
# age                        8508
# price                         0
# seller_n_month                0
# seller_count_reviews       1406
# seller_rating              1513
# page_views                    0
# contacts                      0
# favorites                     0
# dtype: int64

# %%
df_for = df[['days_active', 'photo_count', 'title_length', 'description_length', 'age', 'page_views', 'contacts', 'favorites']]
df_for
# Out:
#        days_active  photo_count  title_length  description_length    age  \
# 0                5            4            18                1155  108.0
# 1               25            2            20                  49    NaN
# 2               25            4            10                 354   60.0
# 3               25            1            17                 869    7.0
# 4               18            4            10                  30   36.0
# ...            ...          ...           ...                 ...    ...
# 49995           22            1            17                 331    4.0
# 49996           25            1            30                  72    0.0
# 49997           25            3            11                 294    2.5
# 49998            7            3            24                 405   18.0
# 49999           25            4            33                  83    8.0
#
#        page_views  contacts  favorites
# 0               0         0          0
# ...

# %%
corr = df_for.corr()

# %%
matrix = np.triu(df_for.corr())
plt.figure(figsize=(12, 10))
ax = sns.heatmap(df_for.corr(), annot=True, mask=matrix, cmap='RdBu', center=0, annot_kws={'size': 16})
ax.tick_params(axis='x', which='major', labelsize=15, color='000000')
ax.tick_params(axis='y', which='major', labelsize=15)

# %%
df[df['price'] <= 1]
# Out:
#       category  days_active  has_video  photo_count  \
# 0       Собаки            5      False            4
# 1       Собаки           25      False            2
# 2        Кошки           25      False            4
# 3        Кошки           25       True            1
# 4        Кошки           18      False            4
# ...        ...          ...        ...          ...
# 49995    Кошки           22      False            1
# 49996   Собаки           25      False            1
# 49997    Кошки           25      False            3
# 49998   Собаки            7      False            3
# 49999   Собаки           25      False            4
#
#                                    title  title_length  description_length  \
# 0                     Харизматичный друг            18                1155
# 1                   Собака в добрые руки            20                  49
# 2                             Добрый кот            10                 354
# ...
